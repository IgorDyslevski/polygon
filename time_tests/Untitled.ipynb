# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
name = 'boxplot5.1.2.png'
name2 = name.replace('png', '2.png')

# %%
image = cv2.imread(name)
image2 = cv2.imread(name2)

# %%
image.shape, image2.shape
# Out:
# ((1800, 1800, 3), (1800, 1800, 3))

# %%
plt.imsave(name.replace('5.', ''), np.concatenate((image, image2), axis=1))

# %%
[[9,9,4],[6,6,8],[2,1,1]]
